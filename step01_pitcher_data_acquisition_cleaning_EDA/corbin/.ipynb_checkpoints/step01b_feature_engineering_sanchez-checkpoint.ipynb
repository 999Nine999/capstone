# %% [markdown]
# # Step01b: Feature Engineering
# In this notebook, we create new features.

# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
import pickle
# %matplotlib inline

# %%
pitches = pd.read_csv('../../data/processed/corbin/corbin_cleaned.csv', 
                      index_col=0)
corbin = pitches.copy()

# %%
corbin.columns
# Out:
# Index(['pitch_type', 'game_date', 'batter', 'release_speed', 'zone', 'stand',
#        'home_team', 'on_3b', 'on_2b', 'on_1b', 'outs_when_up', 'inning',
#        'sv_id', 'release_spin_rate', 'pitch_number', 'opp_score', 'nats_score',
#        'if_fielding_alignment', 'of_fielding_alignment', 'nats_home1_away0',
#        'balls_strikes', 'all_runners'],
#       dtype='object')

# %%
corbin = corbin[['pitch_type', 'game_date', 'sv_id', 'batter', 'pitch_number', 'release_speed', 'zone', 
                 'stand', 'home_team', 'on_3b', 'on_2b', 'on_1b', 'outs_when_up', 'inning', 
                 'release_spin_rate', 'opp_score', 'nats_score','if_fielding_alignment', 
                 'of_fielding_alignment', 'nats_home1_away0', 'balls_strikes', 'all_runners']]

# %%
corbin = corbin.sort_values(by='sv_id')

# %%
corbin['pitch'] = 1

# %%
corbin
# Out:
#      pitch_type   game_date          sv_id  batter  pitch_number  \
# 3298         FF  2019-03-31  190331_173531  607043             1
# 3297         FF  2019-03-31  190331_173544  607043             2
# 3296         SL  2019-03-31  190331_173559  607043             3
# 3295         FF  2019-03-31  190331_173625  607043             4
# 3294         FF  2019-03-31  190331_173656  624413             1
# ...         ...         ...            ...     ...           ...
# 4            FT  2019-09-28  190928_215241  614177             1
# 3            FF  2019-09-28  190928_215257  614177             2
# 2            CH  2019-09-28  190928_215315  614177             3
# 1            SL  2019-09-28  190928_215338  614177             4
# 0            SL  2019-09-28  190928_215410  614177             5
#
#       release_speed  zone stand home_team  on_3b  ...  inning  \
# 3298           90.9    13     L       WSH      0  ...       1
# 3297           90.5     5     L       WSH      0  ...       1
# 3296           80.3     5     L       WSH      0  ...       1
# 3295           93.0     7     L       WSH      0  ...       1
# 3294           92.9     5     R       WSH      0  ...       1
# ...             ...   ...   ...       ...    ...  ...     ...
# 4              93.6    14     R       WSH      0  ...       5
# 3              93.8    13     R       WSH      0  ...       5
# 2              84.0    14     R       WSH      0  ...       5
# 1              83.1    14     R       WSH      0  ...       5
# 0              83.5     8     R       WSH      0  ...       5
#
#       release_spin_rate  opp_score  nats_score  if_fielding_alignment  \
# 3298             2164.0          0           0               Standard
# 3297             2238.0          0           0               Standard
# 3296             2300.0          0           0               Standard
# 3295             2241.0          0           0               Standard
# 3294             2241.0          0           0               Standard
# ...                 ...        ...         ...                    ...
# 4                2287.0          4          10               Standard
# 3                2353.0          4          10               Standard
# 2                1700.0          4          10               Standard
# 1                2538.0          4          10               Standard
# 0                   NaN          4          10               Standard
#
#       of_fielding_alignment  nats_home1_away0 balls_strikes     all_runners  \
# 3298               Standard                 1           0_0  fb:0_sb:0_tb:0
# 3297               Standard                 1           1_0  fb:0_sb:0_tb:0
# 3296               Standard                 1           1_1  fb:0_sb:0_tb:0
# 3295               Standard                 1           1_2  fb:0_sb:0_tb:0
# 3294               Standard                 1           0_0  fb:0_sb:0_tb:0
# ...                     ...               ...           ...             ...
# 4                  Standard                 1           0_0  fb:1_sb:0_tb:0
# 3                  Standard                 1           1_0  fb:1_sb:0_tb:0
# 2                  Standard                 1           1_1  fb:1_sb:0_tb:0
# 1                  Standard                 1           2_1  fb:1_sb:0_tb:0
# 0                  Standard                 1           2_2  fb:1_sb:0_tb:0
#
#       pitch
# 3298      1
# 3297      1
# 3296      1
# 3295      1
# 3294      1
# ...     ...
# 4         1
# 3         1
# 2         1
# 1         1
# 0         1
#
# [3299 rows x 23 columns]

# %% [markdown]
# ## Create running total of pitches thrown in the season

# %%
corbin['pitch_season'] = corbin.pitch.cumsum() - 1

# %% [markdown]
# ## Create running total of pitches thrown in each game

# %%
corbin['pitch_game'] = corbin.groupby(['game_date'])['pitch'].cumsum() - 1

# %%
# corbin.loc[corbin.game_date == '2019-03-28']

# %% [markdown]
# ## Create running total of pitches thrown to each batter per game

# %%
corbin['pitch_bat_gm'] = corbin.groupby(['game_date', 'batter'])['pitch'].cumsum() - 1

# %%
corbin.pitch_number = corbin.pitch_number - 1

# %%
corbin.loc[corbin.batter == 607043]
# Out:
#      pitch_type   game_date          sv_id  batter  pitch_number  \
# 3298         FF  2019-03-31  190331_173531  607043             0
# 3297         FF  2019-03-31  190331_173544  607043             1
# 3296         SL  2019-03-31  190331_173559  607043             2
# 3295         FF  2019-03-31  190331_173625  607043             3
# 3269         SL  2019-03-31  190331_181336  607043             0
# 3268         FF  2019-03-31  190331_181400  607043             1
# 3240         FF  2019-03-31  190331_185053  607043             0
# 3239         FF  2019-03-31  190331_185105  607043             1
# 3238         FF  2019-03-31  190331_185121  607043             2
# 3237         FF  2019-03-31  190331_185149  607043             3
# 3204         FF  2019-04-06  190406_172525  607043             0
# 3203         FT  2019-04-06  190406_172541  607043             1
# 3202         FF  2019-04-06  190406_172602  607043             2
# 3169         FT  2019-04-06  190406_180244  607043             0
# 3168         SL  2019-04-06  190406_180256  607043             1
# 3167         SL  2019-04-06  190406_180311  607043             2
# 3166         FF  2019-04-06  190406_180325  607043             3
# 3165         SL  2019-04-06  190406_180341  607043             4
# 3145         SL  2019-04-06  190406_183843  607043             0
# 3144         SL  2019-04-06  190406_183906  607043             1
# 3143         FF  2019-04-06  190406_183955  607043             2
# 3142         SL  2019-04-06  190406_184025  607043             3
#
#       release_speed  zone stand home_team  on_3b  ...  nats_score  \
# 3298           90.9    13     L       WSH      0  ...           0
# 3297           90.5     5     L       WSH      0  ...           0
# 3296           80.3     5     L       WSH      0  ...           0
# 3295           93.0     7     L       WSH      0  ...           0
# 3269           78.3    13     L       WSH      0  ...           0
# 3268           91.1     5     L       WSH      0  ...           0
# 3240           89.6    14     L       WSH      0  ...           3
# 3239           90.5     7     L       WSH      0  ...           3
# 3238           89.3     2     L       WSH      0  ...           3
# 3237           91.0     4     L       WSH      0  ...           3
# 3204           90.0     7     L       NYM      0  ...           0
# 3203           89.8    12     L       NYM      0  ...           0
# 3202           91.3    12     L       NYM      0  ...           0
# 3169           91.3    14     L       NYM      0  ...           0
# 3168           78.5     1     L       NYM      0  ...           0
# 3167           82.1     8     L       NYM      0  ...           0
# 3166           92.8     7     L       NYM      0  ...           0
# 3165           83.3    13     L       NYM      0  ...           0
# 3145           81.1    13     L       NYM      0  ...           0
# 3144           79.6     8     L       NYM      0  ...           0
# 3143           91.9     1     L       NYM      0  ...           0
# 3142           82.5    13     L       NYM      0  ...           0
#
#       if_fielding_alignment  of_fielding_alignment  nats_home1_away0  \
# 3298               Standard               Standard                 1
# 3297               Standard               Standard                 1
# 3296               Standard               Standard                 1
# 3295               Standard               Standard                 1
# 3269               Standard               Standard                 1
# 3268               Standard               Standard                 1
# 3240               Standard               Standard                 1
# 3239               Standard               Standard                 1
# 3238               Standard               Standard                 1
# 3237               Standard               Standard                 1
# 3204               Standard               Standard                 0
# 3203               Standard               Standard                 0
# 3202               Standard               Standard                 0
# 3169               Standard               Standard                 0
# 3168               Standard               Standard                 0
# 3167               Standard               Standard                 0
# 3166               Standard               Standard                 0
# 3165               Standard               Standard                 0
# 3145               Standard               Standard                 0
# 3144               Standard               Standard                 0
# 3143               Standard               Standard                 0
# 3142               Standard               Standard                 0
#
#       balls_strikes     all_runners  pitch pitch_season pitch_game  \
# 3298            0_0  fb:0_sb:0_tb:0      1            0          0
# 3297            1_0  fb:0_sb:0_tb:0      1            1          1
# 3296            1_1  fb:0_sb:0_tb:0      1            2          2
# 3295            1_2  fb:0_sb:0_tb:0      1            3          3
# 3269            0_0  fb:0_sb:0_tb:0      1           29         29
# 3268            1_0  fb:0_sb:0_tb:0      1           30         30
# 3240            0_0  fb:0_sb:0_tb:0      1           58         58
# 3239            1_0  fb:0_sb:0_tb:0      1           59         59
# 3238            2_0  fb:0_sb:0_tb:0      1           60         60
# 3237            2_1  fb:0_sb:0_tb:0      1           61         61
# 3204            0_0  fb:0_sb:0_tb:0      1           94          0
# 3203            0_1  fb:0_sb:0_tb:0      1           95          1
# 3202            0_2  fb:0_sb:0_tb:0      1           96          2
# 3169            0_0  fb:0_sb:0_tb:0      1          129         35
# 3168            1_0  fb:0_sb:0_tb:0      1          130         36
# 3167            1_1  fb:0_sb:0_tb:0      1          131         37
# 3166            2_1  fb:0_sb:0_tb:0      1          132         38
# 3165            2_2  fb:0_sb:0_tb:0      1          133         39
# 3145            0_0  fb:1_sb:0_tb:0      1          153         59
# 3144            1_0  fb:1_sb:0_tb:0      1          154         60
# 3143            1_1  fb:1_sb:0_tb:0      1          155         61
# 3142            1_2  fb:1_sb:0_tb:0      1          156         62
#
#       pitch_bat_gm
# 3298             0
# 3297             1
# 3296             2
# 3295             3
# 3269             4
# 3268             5
# 3240             6
# 3239             7
# 3238             8
# 3237             9
# 3204             0
# 3203             1
# 3202             2
# 3169             3
# 3168             4
# 3167             5
# 3166             6
# 3165             7
# 3145             8
# 3144             9
# 3143            10
# 3142            11
#
# [22 rows x 26 columns]

# %% [markdown]
# ## Reorder columns

# %%
corbin = corbin.drop(columns = ['pitch'])

# %%
corbin.columns
# Out:
# Index(['pitch_type', 'game_date', 'sv_id', 'batter', 'pitch_number',
#        'release_speed', 'zone', 'stand', 'home_team', 'on_3b', 'on_2b',
#        'on_1b', 'outs_when_up', 'inning', 'release_spin_rate', 'opp_score',
#        'nats_score', 'if_fielding_alignment', 'of_fielding_alignment',
#        'nats_home1_away0', 'balls_strikes', 'all_runners', 'pitch_season',
#        'pitch_game', 'pitch_bat_gm'],
#       dtype='object')

# %%
corbin[['pitch_type', 'game_date', 'sv_id', 'batter', 
        'pitch_number', 'pitch_bat_gm', 'pitch_game', 'pitch_season', 
        'release_speed', 'zone', 'stand', 'home_team', 
        'on_3b', 'on_2b', 'on_1b', 'outs_when_up', 'inning', 
        'release_spin_rate', 'opp_score', 'nats_score', 'if_fielding_alignment', 'of_fielding_alignment',
        'nats_home1_away0', 'balls_strikes', 'all_runners']]
# Out:
#      pitch_type   game_date          sv_id  batter  pitch_number  \
# 3298         FF  2019-03-31  190331_173531  607043             0
# 3297         FF  2019-03-31  190331_173544  607043             1
# 3296         SL  2019-03-31  190331_173559  607043             2
# 3295         FF  2019-03-31  190331_173625  607043             3
# 3294         FF  2019-03-31  190331_173656  624413             0
# ...         ...         ...            ...     ...           ...
# 4            FT  2019-09-28  190928_215241  614177             0
# 3            FF  2019-09-28  190928_215257  614177             1
# 2            CH  2019-09-28  190928_215315  614177             2
# 1            SL  2019-09-28  190928_215338  614177             3
# 0            SL  2019-09-28  190928_215410  614177             4
#
#       pitch_bat_gm  pitch_game  pitch_season  release_speed  zone  ...  \
# 3298             0           0             0           90.9    13  ...
# 3297             1           1             1           90.5     5  ...
# 3296             2           2             2           80.3     5  ...
# 3295             3           3             3           93.0     7  ...
# 3294             0           4             4           92.9     5  ...
# ...            ...         ...           ...            ...   ...  ...
# 4                4          89          3294           93.6    14  ...
# 3                5          90          3295           93.8    13  ...
# 2                6          91          3296           84.0    14  ...
# 1                7          92          3297           83.1    14  ...
# 0                8          93          3298           83.5     8  ...
#
#      outs_when_up inning  release_spin_rate  opp_score  nats_score  \
# 3298            0      1             2164.0          0           0
# 3297            0      1             2238.0          0           0
# 3296            0      1             2300.0          0           0
# 3295            0      1             2241.0          0           0
# 3294            1      1             2241.0          0           0
# ...           ...    ...                ...        ...         ...
# 4               1      5             2287.0          4          10
# 3               1      5             2353.0          4          10
# 2               1      5             1700.0          4          10
# 1               1      5             2538.0          4          10
# 0               1      5                NaN          4          10
#
#       if_fielding_alignment  of_fielding_alignment  nats_home1_away0  \
# 3298               Standard               Standard                 1
# 3297               Standard               Standard                 1
# 3296               Standard               Standard                 1
# 3295               Standard               Standard                 1
# 3294               Standard               Standard                 1
# ...                     ...                    ...               ...
# 4                  Standard               Standard                 1
# 3                  Standard               Standard                 1
# 2                  Standard               Standard                 1
# 1                  Standard               Standard                 1
# 0                  Standard               Standard                 1
#
#       balls_strikes     all_runners
# 3298            0_0  fb:0_sb:0_tb:0
# 3297            1_0  fb:0_sb:0_tb:0
# 3296            1_1  fb:0_sb:0_tb:0
# 3295            1_2  fb:0_sb:0_tb:0
# 3294            0_0  fb:0_sb:0_tb:0
# ...             ...             ...
# 4               0_0  fb:1_sb:0_tb:0
# 3               1_0  fb:1_sb:0_tb:0
# 2               1_1  fb:1_sb:0_tb:0
# 1               2_1  fb:1_sb:0_tb:0
# 0               2_2  fb:1_sb:0_tb:0
#
# [3299 rows x 25 columns]

# %%
outfile = open('../../data/processed/corbin/corbin_clean_new_features.pickle','wb')
pickle.dump(corbin ,outfile)
outfile.close()
