# %% [markdown]
# # Step01b: Feature Engineering
# In this notebook, we create new features.

# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
import pickle
# %matplotlib inline

# %%
pitches = pd.read_csv('../../data/processed/ross/ross_cleaned.csv', 
                      index_col=0)
ross = pitches.copy()

# %%
ross.columns
# Out:
# Index(['pitch_type', 'game_date', 'batter', 'release_speed', 'zone', 'stand',
#        'home_team', 'on_3b', 'on_2b', 'on_1b', 'outs_when_up', 'inning',
#        'sv_id', 'release_spin_rate', 'pitch_number', 'opp_score', 'nats_score',
#        'if_fielding_alignment', 'of_fielding_alignment', 'nats_home1_away0',
#        'balls_strikes', 'all_runners'],
#       dtype='object')

# %%
ross = ross[['pitch_type', 'game_date', 'sv_id', 'batter', 'pitch_number', 'release_speed', 'zone', 
                 'stand', 'home_team', 'on_3b', 'on_2b', 'on_1b', 'outs_when_up', 'inning', 
                 'release_spin_rate', 'opp_score', 'nats_score','if_fielding_alignment', 
                 'of_fielding_alignment', 'nats_home1_away0', 'balls_strikes', 'all_runners']]

# %%
ross = ross.sort_values(by='sv_id')

# %%
ross['pitch'] = 1

# %%
ross
# Out:
#      pitch_type   game_date          sv_id  batter  pitch_number  \
# 1137         FF  2019-04-07  190407_203550  643446             1
# 1136         FF  2019-04-07  190407_203609  643446             2
# 1135         SL  2019-04-07  190407_203643  643446             3
# 1134         FF  2019-04-07  190407_203706  643446             4
# 1133         SL  2019-04-07  190407_203726  643446             5
# ...         ...         ...            ...     ...           ...
# 4            FF  2019-09-29  190929_204035  502273             4
# 3            SI  2019-09-29  190929_204117  644374             1
# 2            SL  2019-09-29  190929_204138  644374             2
# 1            SI  2019-09-29  190929_204203  644374             3
# 0            SI  2019-09-29  190929_204229  644374             4
#
#       release_speed  zone stand home_team  on_3b  ...  inning  \
# 1137           95.9     8     L       NYM      0  ...       9
# 1136           95.3     3     L       NYM      0  ...       9
# 1135           88.4    14     L       NYM      0  ...       9
# 1134           94.4    11     L       NYM      0  ...       9
# 1133           88.2    14     L       NYM      0  ...       9
# ...             ...   ...   ...       ...    ...  ...     ...
# 4              94.7     3     L       WSH      0  ...       6
# 3              93.4    12     R       WSH      0  ...       6
# 2              86.3     1     R       WSH      0  ...       6
# 1              92.9    14     R       WSH      0  ...       6
# 0              93.0     8     R       WSH      0  ...       6
#
#       release_spin_rate  opp_score  nats_score  if_fielding_alignment  \
# 1137             2249.0          6          12               Standard
# 1136             2215.0          6          12               Standard
# 1135             1906.0          6          12               Standard
# 1134             2085.0          6          12               Standard
# 1133             2075.0          6          12               Standard
# ...                 ...        ...         ...                    ...
# 4                1979.0          1           3          Infield shift
# 3                1958.0          1           3               Standard
# 2                1775.0          1           3               Standard
# 1                1998.0          1           3               Standard
# 0                2037.0          1           3               Standard
#
#       of_fielding_alignment  nats_home1_away0 balls_strikes     all_runners  \
# 1137               Standard                 0           0_0  fb:0_sb:0_tb:0
# 1136               Standard                 0           0_1  fb:0_sb:0_tb:0
# 1135               Standard                 0           0_2  fb:0_sb:0_tb:0
# 1134               Standard                 0           1_2  fb:0_sb:0_tb:0
# 1133               Standard                 0           2_2  fb:0_sb:0_tb:0
# ...                     ...               ...           ...             ...
# 4                  Standard                 1           1_2  fb:0_sb:0_tb:0
# 3                  Standard                 1           0_0  fb:1_sb:0_tb:0
# 2                  Standard                 1           1_0  fb:1_sb:0_tb:0
# 1                  Standard                 1           2_0  fb:1_sb:0_tb:0
# 0                  Standard                 1           3_0  fb:1_sb:0_tb:0
#
#       pitch
# 1137      1
# 1136      1
# 1135      1
# 1134      1
# 1133      1
# ...     ...
# 4         1
# 3         1
# 2         1
# 1         1
# 0         1
#
# [1138 rows x 23 columns]

# %% [markdown]
# ## Create running total of pitches thrown in the season

# %%
ross['pitch_season'] = ross.pitch.cumsum() - 1

# %% [markdown]
# ## Create running total of pitches thrown in each game

# %%
ross['pitch_game'] = ross.groupby(['game_date'])['pitch'].cumsum() - 1

# %%
# ross.loc[ross.game_date == '2019-03-28']

# %% [markdown]
# ## Create running total of pitches thrown to each batter per game

# %%
ross['pitch_bat_gm'] = ross.groupby(['game_date', 'batter'])['pitch'].cumsum() - 1

# %%
ross.pitch_number = ross.pitch_number - 1

# %%
ross.loc[ross.batter == 607043]
# Out:
#     pitch_type   game_date          sv_id  batter  pitch_number  \
# 208         FF  2019-09-02  190902_172535  607043             0
# 207         FF  2019-09-02  190902_172607  607043             1
# 206         FF  2019-09-02  190902_172645  607043             2
# 205         SL  2019-09-02  190902_172712  607043             3
# 204         FF  2019-09-02  190902_172748  607043             4
# 203         CH  2019-09-02  190902_172825  607043             5
# 202         SL  2019-09-02  190902_172859  607043             6
# 201         SI  2019-09-02  190902_172937  607043             7
# 200         CU  2019-09-02  190902_173032  607043             8
# 199         FF  2019-09-02  190902_173139  607043             9
# 173         SI  2019-09-02  190902_175728  607043             0
# 172         SL  2019-09-02  190902_175750  607043             1
# 171         SI  2019-09-02  190902_175821  607043             2
# 170         SI  2019-09-02  190902_175848  607043             3
# 169         SL  2019-09-02  190902_175924  607043             4
#
#      release_speed  zone stand home_team  on_3b  ...  nats_score  \
# 208           94.0     2     L       WSH      0  ...           0
# 207           94.4    12     L       WSH      0  ...           0
# 206           94.2    12     L       WSH      0  ...           0
# 205           87.4    14     L       WSH      0  ...           0
# 204           93.4     2     L       WSH      0  ...           0
# 203           89.3    13     L       WSH      0  ...           0
# 202           88.6     4     L       WSH      0  ...           0
# 201           94.8    11     L       WSH      0  ...           0
# 200           80.9    11     L       WSH      0  ...           0
# 199           94.7     1     L       WSH      0  ...           0
# 173           92.7    11     L       WSH      0  ...           0
# 172           88.9     8     L       WSH      0  ...           0
# 171           92.0    11     L       WSH      0  ...           0
# 170           92.8    11     L       WSH      0  ...           0
# 169           86.4    11     L       WSH      0  ...           0
#
#      if_fielding_alignment  of_fielding_alignment  nats_home1_away0  \
# 208               Standard               Standard                 1
# 207               Standard               Standard                 1
# 206               Standard               Standard                 1
# 205               Standard               Standard                 1
# 204               Standard               Standard                 1
# 203               Standard               Standard                 1
# 202               Standard               Standard                 1
# 201               Standard               Standard                 1
# 200               Standard               Standard                 1
# 199               Standard               Standard                 1
# 173               Standard               Standard                 1
# 172               Standard               Standard                 1
# 171               Standard               Standard                 1
# 170               Standard               Standard                 1
# 169               Standard               Standard                 1
#
#      balls_strikes     all_runners  pitch pitch_season pitch_game  \
# 208            0_0  fb:1_sb:0_tb:0      1          929         18
# 207            0_1  fb:1_sb:0_tb:0      1          930         19
# 206            0_2  fb:1_sb:0_tb:0      1          931         20
# 205            1_2  fb:1_sb:0_tb:0      1          932         21
# 204            2_2  fb:1_sb:0_tb:0      1          933         22
# 203            2_2  fb:1_sb:0_tb:0      1          934         23
# 202            3_2  fb:1_sb:0_tb:0      1          935         24
# 201            3_2  fb:1_sb:0_tb:0      1          936         25
# 200            3_2  fb:1_sb:0_tb:0      1          937         26
# 199            3_2  fb:1_sb:0_tb:0      1          938         27
# 173            0_0  fb:1_sb:0_tb:0      1          964         53
# 172            1_0  fb:1_sb:0_tb:0      1          965         54
# 171            1_1  fb:1_sb:0_tb:0      1          966         55
# 170            2_1  fb:1_sb:0_tb:0      1          967         56
# 169            3_1  fb:1_sb:0_tb:0      1          968         57
#
#      pitch_bat_gm
# 208             0
# 207             1
# 206             2
# 205             3
# 204             4
# 203             5
# 202             6
# 201             7
# 200             8
# 199             9
# 173            10
# 172            11
# 171            12
# 170            13
# 169            14
#
# [15 rows x 26 columns]

# %% [markdown]
# ## Reorder columns

# %%
ross = ross.drop(columns = ['pitch'])

# %%
ross.columns
# Out:
# Index(['pitch_type', 'game_date', 'sv_id', 'batter', 'pitch_number',
#        'release_speed', 'zone', 'stand', 'home_team', 'on_3b', 'on_2b',
#        'on_1b', 'outs_when_up', 'inning', 'release_spin_rate', 'opp_score',
#        'nats_score', 'if_fielding_alignment', 'of_fielding_alignment',
#        'nats_home1_away0', 'balls_strikes', 'all_runners', 'pitch_season',
#        'pitch_game', 'pitch_bat_gm'],
#       dtype='object')

# %%
ross[['pitch_type', 'game_date', 'sv_id', 'batter', 
        'pitch_number', 'pitch_bat_gm', 'pitch_game', 'pitch_season', 
        'release_speed', 'zone', 'stand', 'home_team', 
        'on_3b', 'on_2b', 'on_1b', 'outs_when_up', 'inning', 
        'release_spin_rate', 'opp_score', 'nats_score', 'if_fielding_alignment', 'of_fielding_alignment',
        'nats_home1_away0', 'balls_strikes', 'all_runners']]
# Out:
#      pitch_type   game_date          sv_id  batter  pitch_number  \
# 1137         FF  2019-04-07  190407_203550  643446             0
# 1136         FF  2019-04-07  190407_203609  643446             1
# 1135         SL  2019-04-07  190407_203643  643446             2
# 1134         FF  2019-04-07  190407_203706  643446             3
# 1133         SL  2019-04-07  190407_203726  643446             4
# ...         ...         ...            ...     ...           ...
# 4            FF  2019-09-29  190929_204035  502273             3
# 3            SI  2019-09-29  190929_204117  644374             0
# 2            SL  2019-09-29  190929_204138  644374             1
# 1            SI  2019-09-29  190929_204203  644374             2
# 0            SI  2019-09-29  190929_204229  644374             3
#
#       pitch_bat_gm  pitch_game  pitch_season  release_speed  zone  ...  \
# 1137             0           0             0           95.9     8  ...
# 1136             1           1             1           95.3     3  ...
# 1135             2           2             2           88.4    14  ...
# 1134             3           3             3           94.4    11  ...
# 1133             4           4             4           88.2    14  ...
# ...            ...         ...           ...            ...   ...  ...
# 4               11          73          1133           94.7     3  ...
# 3                6          74          1134           93.4    12  ...
# 2                7          75          1135           86.3     1  ...
# 1                8          76          1136           92.9    14  ...
# 0                9          77          1137           93.0     8  ...
#
#      outs_when_up inning  release_spin_rate  opp_score  nats_score  \
# 1137            0      9             2249.0          6          12
# 1136            0      9             2215.0          6          12
# 1135            0      9             1906.0          6          12
# 1134            0      9             2085.0          6          12
# 1133            0      9             2075.0          6          12
# ...           ...    ...                ...        ...         ...
# 4               2      6             1979.0          1           3
# 3               2      6             1958.0          1           3
# 2               2      6             1775.0          1           3
# 1               2      6             1998.0          1           3
# 0               2      6             2037.0          1           3
#
#       if_fielding_alignment  of_fielding_alignment  nats_home1_away0  \
# 1137               Standard               Standard                 0
# 1136               Standard               Standard                 0
# 1135               Standard               Standard                 0
# 1134               Standard               Standard                 0
# 1133               Standard               Standard                 0
# ...                     ...                    ...               ...
# 4             Infield shift               Standard                 1
# 3                  Standard               Standard                 1
# 2                  Standard               Standard                 1
# 1                  Standard               Standard                 1
# 0                  Standard               Standard                 1
#
#       balls_strikes     all_runners
# 1137            0_0  fb:0_sb:0_tb:0
# 1136            0_1  fb:0_sb:0_tb:0
# 1135            0_2  fb:0_sb:0_tb:0
# 1134            1_2  fb:0_sb:0_tb:0
# 1133            2_2  fb:0_sb:0_tb:0
# ...             ...             ...
# 4               1_2  fb:0_sb:0_tb:0
# 3               0_0  fb:1_sb:0_tb:0
# 2               1_0  fb:1_sb:0_tb:0
# 1               2_0  fb:1_sb:0_tb:0
# 0               3_0  fb:1_sb:0_tb:0
#
# [1138 rows x 25 columns]

# %%
outfile = open('../../data/processed/ross/ross_clean_new_features.pickle','wb')
pickle.dump(ross ,outfile)
outfile.close()
