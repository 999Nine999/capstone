# %% [markdown]
# # Step01b: Feature Engineering
# In this notebook, we create new features.

# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
import pickle
# %matplotlib inline

# %%
pitches = pd.read_csv('../../data/processed/sanchez/sanchez_cleaned.csv', 
                      index_col=0)
sanchez = pitches.copy()

# %%
sanchez.columns
# Out:
# Index(['pitch_type', 'game_date', 'batter', 'release_speed', 'zone', 'stand',
#        'home_team', 'on_3b', 'on_2b', 'on_1b', 'outs_when_up', 'inning',
#        'sv_id', 'release_spin_rate', 'pitch_number', 'opp_score', 'nats_score',
#        'if_fielding_alignment', 'of_fielding_alignment', 'nats_home1_away0',
#        'balls_strikes', 'all_runners'],
#       dtype='object')

# %%
sanchez = sanchez[['pitch_type', 'game_date', 'sv_id', 'batter', 'pitch_number', 'release_speed', 'zone', 
                 'stand', 'home_team', 'on_3b', 'on_2b', 'on_1b', 'outs_when_up', 'inning', 
                 'release_spin_rate', 'opp_score', 'nats_score','if_fielding_alignment', 
                 'of_fielding_alignment', 'nats_home1_away0', 'balls_strikes', 'all_runners']]

# %%
sanchez = sanchez.sort_values(by='sv_id')

# %%
sanchez['pitch'] = 1

# %%
sanchez
# Out:
#      pitch_type   game_date          sv_id  batter  pitch_number  \
# 2689         FF  2019-04-03  190403_170525  457705             1
# 2688         FC  2019-04-03  190403_170539  457705             2
# 2687         FF  2019-04-03  190403_170602  457705             3
# 2686         FC  2019-04-03  190403_170619  457705             4
# 2685         FF  2019-04-03  190403_170648  516416             1
# ...         ...         ...            ...     ...           ...
# 4            FF  2019-09-25  190926_004925  595284             2
# 3            CH  2019-09-25  190926_004953  595284             3
# 2            FS  2019-09-25  190926_005029  595284             4
# 1            FC  2019-09-25  190926_005103  595284             5
# 0            FS  2019-09-25  190926_005132  595284             6
#
#       release_speed  zone stand home_team  on_3b  ...  inning  \
# 2689           89.1  14.0     R       WSH      0  ...       1
# 2688           86.2   8.0     R       WSH      0  ...       1
# 2687           91.2  12.0     R       WSH      0  ...       1
# 2686           88.5   7.0     R       WSH      0  ...       1
# 2685           91.6   9.0     R       WSH      0  ...       1
# ...             ...   ...   ...       ...    ...  ...     ...
# 4              88.6   7.0     L       WSH      0  ...       7
# 3              71.7  13.0     L       WSH      0  ...       7
# 2              83.7  13.0     L       WSH      0  ...       7
# 1              90.3  11.0     L       WSH      0  ...       7
# 0              84.7  13.0     L       WSH      1  ...       7
#
#       release_spin_rate  opp_score  nats_score  if_fielding_alignment  \
# 2689             2207.0          0           0               Standard
# 2688             2402.0          0           0               Standard
# 2687             2269.0          0           0               Standard
# 2686             2361.0          0           0               Standard
# 2685             2241.0          0           0               Standard
# ...                 ...        ...         ...                    ...
# 4                2324.0          2           1          Infield shift
# 3                   NaN          2           1          Infield shift
# 2                1736.0          2           1          Infield shift
# 1                2220.0          2           1          Infield shift
# 0                1685.0          2           1          Infield shift
#
#       of_fielding_alignment  nats_home1_away0 balls_strikes     all_runners  \
# 2689               Standard                 1           0_0  fb:0_sb:0_tb:0
# 2688               Standard                 1           0_1  fb:0_sb:0_tb:0
# 2687               Standard                 1           0_2  fb:0_sb:0_tb:0
# 2686               Standard                 1           1_2  fb:0_sb:0_tb:0
# 2685               Standard                 1           0_0  fb:0_sb:0_tb:0
# ...                     ...               ...           ...             ...
# 4                  Standard                 1           0_1  fb:1_sb:0_tb:0
# 3                  Standard                 1           0_2  fb:0_sb:1_tb:0
# 2                  Standard                 1           1_2  fb:0_sb:1_tb:0
# 1                  Standard                 1           2_2  fb:0_sb:1_tb:0
# 0                  Standard                 1           3_2  fb:0_sb:0_tb:1
#
#       pitch
# 2689      1
# 2688      1
# 2687      1
# 2686      1
# 2685      1
# ...     ...
# 4         1
# 3         1
# 2         1
# 1         1
# 0         1
#
# [2690 rows x 23 columns]

# %% [markdown]
# ## Create running total of pitches thrown in the season

# %%
sanchez['pitch_season'] = sanchez.pitch.cumsum() - 1

# %% [markdown]
# ## Create running total of pitches thrown in each game

# %%
sanchez['pitch_game'] = sanchez.groupby(['game_date'])['pitch'].cumsum() - 1

# %%
# sanchez.loc[sanchez.game_date == '2019-03-28']

# %% [markdown]
# ## Create running total of pitches thrown to each batter per game

# %%
sanchez['pitch_bat_gm'] = sanchez.groupby(['game_date', 'batter'])['pitch'].cumsum() - 1

# %%
sanchez.pitch_number = sanchez.pitch_number - 1

# %%
sanchez.loc[sanchez.batter == 607043]
# Out:
#      pitch_type   game_date          sv_id  batter  pitch_number  \
# 1928         FF  2019-05-16  190516_173622  607043             0
# 1927         FF  2019-05-16  190516_173700  607043             1
# 1926         FF  2019-05-16  190516_173734  607043             2
# 1925         FF  2019-05-16  190516_173805  607043             3
# 1924         FS  2019-05-16  190516_173842  607043             4
# 1923         FF  2019-05-16  190516_173904  607043             5
# 1922         FS  2019-05-16  190516_173929  607043             6
# 1921         FC  2019-05-16  190516_174007  607043             7
#
#       release_speed  zone stand home_team  on_3b  ...  nats_score  \
# 1928           89.3   6.0     L       WSH      0  ...           4
# 1927           88.3  12.0     L       WSH      0  ...           4
# 1926           89.6   6.0     L       WSH      0  ...           4
# 1925           91.3   5.0     L       WSH      0  ...           4
# 1924           83.7  13.0     L       WSH      0  ...           4
# 1923           89.2  13.0     L       WSH      0  ...           4
# 1922           84.8   4.0     L       WSH      0  ...           4
# 1921           87.8  11.0     L       WSH      0  ...           4
#
#       if_fielding_alignment  of_fielding_alignment  nats_home1_away0  \
# 1928               Standard               Standard                 1
# 1927               Standard               Standard                 1
# 1926               Standard               Standard                 1
# 1925          Infield shift               Standard                 1
# 1924          Infield shift               Standard                 1
# 1923          Infield shift               Standard                 1
# 1922          Infield shift               Standard                 1
# 1921          Infield shift               Standard                 1
#
#       balls_strikes     all_runners  pitch pitch_season pitch_game  \
# 1928            0_0  fb:1_sb:0_tb:0      1          761         23
# 1927            0_1  fb:1_sb:0_tb:0      1          762         24
# 1926            1_1  fb:1_sb:0_tb:0      1          763         25
# 1925            1_2  fb:1_sb:0_tb:0      1          764         26
# 1924            1_2  fb:1_sb:0_tb:0      1          765         27
# 1923            2_2  fb:1_sb:0_tb:0      1          766         28
# 1922            3_2  fb:1_sb:0_tb:0      1          767         29
# 1921            3_2  fb:1_sb:0_tb:0      1          768         30
#
#       pitch_bat_gm
# 1928             0
# 1927             1
# 1926             2
# 1925             3
# 1924             4
# 1923             5
# 1922             6
# 1921             7
#
# [8 rows x 26 columns]

# %% [markdown]
# ## Reorder columns

# %%
sanchez = sanchez.drop(columns = ['pitch'])

# %%
sanchez.columns
# Out:
# Index(['pitch_type', 'game_date', 'sv_id', 'batter', 'pitch_number',
#        'release_speed', 'zone', 'stand', 'home_team', 'on_3b', 'on_2b',
#        'on_1b', 'outs_when_up', 'inning', 'release_spin_rate', 'opp_score',
#        'nats_score', 'if_fielding_alignment', 'of_fielding_alignment',
#        'nats_home1_away0', 'balls_strikes', 'all_runners', 'pitch_season',
#        'pitch_game', 'pitch_bat_gm'],
#       dtype='object')

# %%
sanchez[['pitch_type', 'game_date', 'sv_id', 'batter', 
        'pitch_number', 'pitch_bat_gm', 'pitch_game', 'pitch_season', 
        'release_speed', 'zone', 'stand', 'home_team', 
        'on_3b', 'on_2b', 'on_1b', 'outs_when_up', 'inning', 
        'release_spin_rate', 'opp_score', 'nats_score', 'if_fielding_alignment', 'of_fielding_alignment',
        'nats_home1_away0', 'balls_strikes', 'all_runners']]
# Out:
#      pitch_type   game_date          sv_id  batter  pitch_number  \
# 2689         FF  2019-04-03  190403_170525  457705             0
# 2688         FC  2019-04-03  190403_170539  457705             1
# 2687         FF  2019-04-03  190403_170602  457705             2
# 2686         FC  2019-04-03  190403_170619  457705             3
# 2685         FF  2019-04-03  190403_170648  516416             0
# ...         ...         ...            ...     ...           ...
# 4            FF  2019-09-25  190926_004925  595284             1
# 3            CH  2019-09-25  190926_004953  595284             2
# 2            FS  2019-09-25  190926_005029  595284             3
# 1            FC  2019-09-25  190926_005103  595284             4
# 0            FS  2019-09-25  190926_005132  595284             5
#
#       pitch_bat_gm  pitch_game  pitch_season  release_speed  zone  ...  \
# 2689             0           0             0           89.1  14.0  ...
# 2688             1           1             1           86.2   8.0  ...
# 2687             2           2             2           91.2  12.0  ...
# 2686             3           3             3           88.5   7.0  ...
# 2685             0           4             4           91.6   9.0  ...
# ...            ...         ...           ...            ...   ...  ...
# 4                8          85          2685           88.6   7.0  ...
# 3                9          86          2686           71.7  13.0  ...
# 2               10          87          2687           83.7  13.0  ...
# 1               11          88          2688           90.3  11.0  ...
# 0               12          89          2689           84.7  13.0  ...
#
#      outs_when_up inning  release_spin_rate  opp_score  nats_score  \
# 2689            0      1             2207.0          0           0
# 2688            0      1             2402.0          0           0
# 2687            0      1             2269.0          0           0
# 2686            0      1             2361.0          0           0
# 2685            1      1             2241.0          0           0
# ...           ...    ...                ...        ...         ...
# 4               2      7             2324.0          2           1
# 3               2      7                NaN          2           1
# 2               2      7             1736.0          2           1
# 1               2      7             2220.0          2           1
# 0               2      7             1685.0          2           1
#
#       if_fielding_alignment  of_fielding_alignment  nats_home1_away0  \
# 2689               Standard               Standard                 1
# 2688               Standard               Standard                 1
# 2687               Standard               Standard                 1
# 2686               Standard               Standard                 1
# 2685               Standard               Standard                 1
# ...                     ...                    ...               ...
# 4             Infield shift               Standard                 1
# 3             Infield shift               Standard                 1
# 2             Infield shift               Standard                 1
# 1             Infield shift               Standard                 1
# 0             Infield shift               Standard                 1
#
#       balls_strikes     all_runners
# 2689            0_0  fb:0_sb:0_tb:0
# 2688            0_1  fb:0_sb:0_tb:0
# 2687            0_2  fb:0_sb:0_tb:0
# 2686            1_2  fb:0_sb:0_tb:0
# 2685            0_0  fb:0_sb:0_tb:0
# ...             ...             ...
# 4               0_1  fb:1_sb:0_tb:0
# 3               0_2  fb:0_sb:1_tb:0
# 2               1_2  fb:0_sb:1_tb:0
# 1               2_2  fb:0_sb:1_tb:0
# 0               3_2  fb:0_sb:0_tb:1
#
# [2690 rows x 25 columns]

# %%
outfile = open('../../data/processed/sanchez/sanchez_clean_new_features.pickle','wb')
pickle.dump(sanchez ,outfile)
outfile.close()
