# %% [markdown]
# # Step01b: Feature Engineering
# In this notebook, we create new features.

# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
import pickle
# %matplotlib inline

# %%
pitches = pd.read_csv('../../data/processed/scherzer/madmax_cleaned_2015_to_2019.csv', 
                      index_col=0)
madmax = pitches.copy()

# %%
madmax.columns
# Out:
# Index(['pitch_type', 'game_date', 'batter', 'release_speed', 'zone', 'stand',
#        'home_team', 'on_3b', 'on_2b', 'on_1b', 'outs_when_up', 'inning',
#        'sv_id', 'release_spin_rate', 'pitch_number', 'opp_score', 'nats_score',
#        'if_fielding_alignment', 'of_fielding_alignment', 'nats_home1_away0',
#        'balls_strikes', 'all_runners'],
#       dtype='object')

# %%
madmax = madmax[['pitch_type', 'game_date', 'sv_id', 'batter', 'pitch_number', 'release_speed', 'zone', 
                 'stand', 'home_team', 'on_3b', 'on_2b', 'on_1b', 'outs_when_up', 'inning', 
                 'release_spin_rate', 'opp_score', 'nats_score','if_fielding_alignment', 
                 'of_fielding_alignment', 'nats_home1_away0', 'balls_strikes', 'all_runners']]

# %%
madmax.game_date = pd.to_datetime(madmax.game_date)

# %%
madmax = madmax.sort_values(by=['game_date', 'sv_id'])

# %%
madmax['pitch'] = 1

# %%
madmax
# Out:
#       pitch_type  game_date          sv_id  batter  pitch_number  \
# 16295         FF 2015-04-06  150406_160913  434158             1
# 16294         FF 2015-04-06  150406_160925  434158             2
# 16293         FF 2015-04-06  150406_160940  434158             3
# 16292         CH 2015-04-06  150406_160954  434158             4
# 16291         FF 2015-04-06  150406_161010  434158             5
# ...          ...        ...            ...     ...           ...
# 4             CU 2019-09-24  190925_005705  664068             2
# 3             SL 2019-09-24  190925_005726  664068             3
# 2             FF 2019-09-24  190925_005750  664068             4
# 1             CH 2019-09-24  190925_005823  664068             5
# 0             FF 2019-09-24  190925_005920  656514             1
#
#        release_speed  zone stand home_team  on_3b  ...  inning  \
# 16295           91.2  13.0     L       WSH      0  ...       1
# 16294           94.2  11.0     L       WSH      0  ...       1
# 16293           95.6  11.0     L       WSH      0  ...       1
# 16292           87.2  14.0     L       WSH      0  ...       1
# 16291           94.7  11.0     L       WSH      0  ...       1
# ...              ...   ...   ...       ...    ...  ...     ...
# 4               79.1   4.0     R       WSH      0  ...       6
# 3               84.8  14.0     R       WSH      0  ...       6
# 2               97.4   8.0     R       WSH      0  ...       6
# 1               84.4   9.0     R       WSH      0  ...       6
# 0               92.7   6.0     L       WSH      0  ...       6
#
#        release_spin_rate  opp_score  nats_score  if_fielding_alignment  \
# 16295             2338.0          0           0              Strategic
# 16294             2613.0          0           0              Strategic
# 16293             2639.0          0           0              Strategic
# 16292             1765.0          0           0              Strategic
# 16291             2486.0          0           0              Strategic
# ...                  ...        ...         ...                    ...
# 4                 2818.0          4           2               Standard
# 3                 2295.0          4           2               Standard
# 2                 2465.0          4           2               Standard
# 1                 1494.0          4           2               Standard
# 0                 2299.0          4           2          Infield shift
#
#        of_fielding_alignment  nats_home1_away0 balls_strikes     all_runners  \
# 16295               Standard                 1           0_0  fb:0_sb:0_tb:0
# 16294               Standard                 1           0_1  fb:0_sb:0_tb:0
# 16293               Standard                 1           0_2  fb:0_sb:0_tb:0
# 16292               Standard                 1           1_2  fb:0_sb:0_tb:0
# 16291               Standard                 1           2_2  fb:0_sb:0_tb:0
# ...                      ...               ...           ...             ...
# 4                   Standard                 1           0_1  fb:0_sb:0_tb:0
# 3                   Standard                 1           0_2  fb:0_sb:0_tb:0
# 2                   Standard                 1           1_2  fb:0_sb:0_tb:0
# 1                   Standard                 1           1_2  fb:0_sb:0_tb:0
# 0                   Standard                 1           0_0  fb:1_sb:0_tb:0
#
#        pitch
# 16295      1
# 16294      1
# 16293      1
# 16292      1
# 16291      1
# ...      ...
# 4          1
# 3          1
# 2          1
# 1          1
# 0          1
#
# [16296 rows x 23 columns]

# %%
# madmax.info();

# drop rows with not pitch_type, disregard other nulls as these are addressed later on.

# %%
madmax = madmax.loc[madmax.pitch_type.isnull() == False]

# %% [markdown]
# ## Create running total of pitches thrown in the season

# %%
madmax['pitch_season'] = madmax.groupby(madmax.game_date.dt.year).pitch.cumsum() - 1
# Out:
# /Users/algrhythm/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Create running total of pitches thrown in each game

# %%
madmax['pitch_game'] = madmax.groupby(['game_date'])['pitch'].cumsum() - 1
# Out:
# /Users/algrhythm/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# madmax.loc[madmax.game_date == '2019-03-28']

# %% [markdown]
# ## Create running total of pitches thrown to each batter per game

# %%
madmax['pitch_bat_gm'] = madmax.groupby(['game_date', 'batter'])['pitch'].cumsum() - 1
# Out:
# /Users/algrhythm/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
madmax.pitch_number = madmax.pitch_number - 1
# Out:
# /Users/algrhythm/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
madmax[['pitch_type', 'game_date','batter', 'pitch_number', 'pitch_bat_gm']].loc[madmax.batter == 607043]
# Out:
#       pitch_type  game_date  batter  pitch_number  pitch_bat_gm
# 11238         FF 2016-06-29  607043             0             0
# 11237         FF 2016-06-29  607043             1             1
# 11236         CH 2016-06-29  607043             2             2
# 11235         FC 2016-06-29  607043             3             3
# 11197         CU 2016-06-29  607043             0             4
# ...          ...        ...     ...           ...           ...
# 417           CU 2019-09-03  607043             1            12
# 416           FC 2019-09-03  607043             2            13
# 415           FF 2019-09-03  607043             3            14
# 414           FC 2019-09-03  607043             4            15
# 413           FC 2019-09-03  607043             5            16
#
# [113 rows x 5 columns]

# %% [markdown]
# ## Reorder columns

# %%
madmax = madmax.drop(columns = ['pitch'])

# %%
madmax.columns
# Out:
# Index(['pitch_type', 'game_date', 'sv_id', 'batter', 'pitch_number',
#        'release_speed', 'zone', 'stand', 'home_team', 'on_3b', 'on_2b',
#        'on_1b', 'outs_when_up', 'inning', 'release_spin_rate', 'opp_score',
#        'nats_score', 'if_fielding_alignment', 'of_fielding_alignment',
#        'nats_home1_away0', 'balls_strikes', 'all_runners', 'pitch_season',
#        'pitch_game', 'pitch_bat_gm'],
#       dtype='object')

# %%
madmax[['pitch_type', 'game_date', 'sv_id', 'batter', 
        'pitch_number', 'pitch_bat_gm', 'pitch_game', 'pitch_season', 
        'release_speed', 'zone', 'stand', 'home_team', 
        'on_3b', 'on_2b', 'on_1b', 'outs_when_up', 'inning', 
        'release_spin_rate', 'opp_score', 'nats_score', 'if_fielding_alignment', 'of_fielding_alignment',
        'nats_home1_away0', 'balls_strikes', 'all_runners']]
# Out:
#       pitch_type  game_date          sv_id  batter  pitch_number  \
# 16295         FF 2015-04-06  150406_160913  434158             0
# 16294         FF 2015-04-06  150406_160925  434158             1
# 16293         FF 2015-04-06  150406_160940  434158             2
# 16292         CH 2015-04-06  150406_160954  434158             3
# 16291         FF 2015-04-06  150406_161010  434158             4
# ...          ...        ...            ...     ...           ...
# 4             CU 2019-09-24  190925_005705  664068             1
# 3             SL 2019-09-24  190925_005726  664068             2
# 2             FF 2019-09-24  190925_005750  664068             3
# 1             CH 2019-09-24  190925_005823  664068             4
# 0             FF 2019-09-24  190925_005920  656514             0
#
#        pitch_bat_gm  pitch_game  pitch_season  release_speed  zone  ...  \
# 16295             0           0             0           91.2  13.0  ...
# 16294             1           1             1           94.2  11.0  ...
# 16293             2           2             2           95.6  11.0  ...
# 16292             3           3             3           87.2  14.0  ...
# 16291             4           4             4           94.7  11.0  ...
# ...             ...         ...           ...            ...   ...  ...
# 4                11          96          2765           79.1   4.0  ...
# 3                12          97          2766           84.8  14.0  ...
# 2                13          98          2767           97.4   8.0  ...
# 1                14          99          2768           84.4   9.0  ...
# 0                 7         100          2769           92.7   6.0  ...
#
#       outs_when_up inning  release_spin_rate  opp_score  nats_score  \
# 16295            0      1             2338.0          0           0
# 16294            0      1             2613.0          0           0
# 16293            0      1             2639.0          0           0
# 16292            0      1             1765.0          0           0
# 16291            0      1             2486.0          0           0
# ...            ...    ...                ...        ...         ...
# 4                2      6             2818.0          4           2
# 3                2      6             2295.0          4           2
# 2                2      6             2465.0          4           2
# 1                2      6             1494.0          4           2
# 0                2      6             2299.0          4           2
#
#        if_fielding_alignment  of_fielding_alignment  nats_home1_away0  \
# 16295              Strategic               Standard                 1
# 16294              Strategic               Standard                 1
# 16293              Strategic               Standard                 1
# 16292              Strategic               Standard                 1
# 16291              Strategic               Standard                 1
# ...                      ...                    ...               ...
# 4                   Standard               Standard                 1
# 3                   Standard               Standard                 1
# 2                   Standard               Standard                 1
# 1                   Standard               Standard                 1
# 0              Infield shift               Standard                 1
#
#        balls_strikes     all_runners
# 16295            0_0  fb:0_sb:0_tb:0
# 16294            0_1  fb:0_sb:0_tb:0
# 16293            0_2  fb:0_sb:0_tb:0
# 16292            1_2  fb:0_sb:0_tb:0
# 16291            2_2  fb:0_sb:0_tb:0
# ...              ...             ...
# 4                0_1  fb:0_sb:0_tb:0
# 3                0_2  fb:0_sb:0_tb:0
# 2                1_2  fb:0_sb:0_tb:0
# 1                1_2  fb:0_sb:0_tb:0
# 0                0_0  fb:1_sb:0_tb:0
#
# [16259 rows x 25 columns]

# %%
outfile = open('../../data/processed/scherzer/scherzer_clean_new_features_2015_to_2019.pickle','wb')
pickle.dump(madmax ,outfile)
outfile.close()
