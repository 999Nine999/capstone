# %% [markdown]
# # Step01b: Feature Engineering
# In this notebook, we create new features.

# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
import pickle
# %matplotlib inline

# %%
pitches = pd.read_csv('../../data/processed/madmax_cleaned.csv', 
                      index_col=0)
madmax = pitches.copy()

# %%
madmax.columns
# Out:
# Index(['pitch_type', 'game_date', 'batter', 'release_speed', 'zone', 'stand',
#        'home_team', 'on_3b', 'on_2b', 'on_1b', 'outs_when_up', 'inning',
#        'sv_id', 'release_spin_rate', 'pitch_number', 'opp_score', 'nats_score',
#        'if_fielding_alignment', 'of_fielding_alignment', 'nats_home1_away0',
#        'balls_strikes', 'all_runners'],
#       dtype='object')

# %%
madmax = madmax[['pitch_type', 'game_date', 'sv_id', 'batter', 'pitch_number', 'release_speed', 'zone', 
                 'stand', 'home_team', 'on_3b', 'on_2b', 'on_1b', 'outs_when_up', 'inning', 
                 'release_spin_rate', 'opp_score', 'nats_score','if_fielding_alignment', 
                 'of_fielding_alignment', 'nats_home1_away0', 'balls_strikes', 'all_runners']]

# %%
madmax = madmax.sort_values(by='sv_id')

# %%
madmax['pitch'] = 1

# %%
madmax
# Out:
#      pitch_type   game_date          sv_id  batter  pitch_number  \
# 2769         FF  2019-03-28  190328_170717  607043             1
# 2768         FF  2019-03-28  190328_170732  607043             2
# 2767         FF  2019-03-28  190328_170752  607043             3
# 2766         SL  2019-03-28  190328_170825  624413             1
# 2765         FF  2019-03-28  190328_170842  624413             2
# ...         ...         ...            ...     ...           ...
# 4            CU  2019-09-24  190925_005705  664068             2
# 3            SL  2019-09-24  190925_005726  664068             3
# 2            FF  2019-09-24  190925_005750  664068             4
# 1            CH  2019-09-24  190925_005823  664068             5
# 0            FF  2019-09-24  190925_005920  656514             1
#
#       release_speed  zone stand home_team  on_3b  ...  inning  \
# 2769           93.7   6.0     L       WSH      0  ...       1
# 2768           94.2   5.0     L       WSH      0  ...       1
# 2767           96.3   5.0     L       WSH      0  ...       1
# 2766           85.6   6.0     R       WSH      0  ...       1
# 2765           95.5  12.0     R       WSH      0  ...       1
# ...             ...   ...   ...       ...    ...  ...     ...
# 4              79.1   4.0     R       WSH      0  ...       6
# 3              84.8  14.0     R       WSH      0  ...       6
# 2              97.4   8.0     R       WSH      0  ...       6
# 1              84.4   9.0     R       WSH      0  ...       6
# 0              92.7   6.0     L       WSH      0  ...       6
#
#       release_spin_rate  opp_score  nats_score  if_fielding_alignment  \
# 2769             2584.0          0           0          Infield shift
# 2768             2545.0          0           0          Infield shift
# 2767             2738.0          0           0          Infield shift
# 2766             2370.0          0           0          Infield shift
# 2765             2632.0          0           0          Infield shift
# ...                 ...        ...         ...                    ...
# 4                2818.0          4           2               Standard
# 3                2295.0          4           2               Standard
# 2                2465.0          4           2               Standard
# 1                1494.0          4           2               Standard
# 0                2299.0          4           2          Infield shift
#
#       of_fielding_alignment  nats_home1_away0 balls_strikes     all_runners  \
# 2769               Standard                 1           0_0  fb:0_sb:0_tb:0
# 2768               Standard                 1           0_1  fb:0_sb:0_tb:0
# 2767               Standard                 1           0_2  fb:0_sb:0_tb:0
# 2766               Standard                 1           0_0  fb:0_sb:0_tb:0
# 2765               Standard                 1           0_1  fb:0_sb:0_tb:0
# ...                     ...               ...           ...             ...
# 4                  Standard                 1           0_1  fb:0_sb:0_tb:0
# 3                  Standard                 1           0_2  fb:0_sb:0_tb:0
# 2                  Standard                 1           1_2  fb:0_sb:0_tb:0
# 1                  Standard                 1           1_2  fb:0_sb:0_tb:0
# 0                  Standard                 1           0_0  fb:1_sb:0_tb:0
#
#       pitch
# 2769      1
# 2768      1
# 2767      1
# 2766      1
# 2765      1
# ...     ...
# 4         1
# 3         1
# 2         1
# 1         1
# 0         1
#
# [2770 rows x 23 columns]

# %% [markdown]
# ## Create running total of pitches thrown in the season

# %%
madmax['pitch_season'] = madmax.pitch.cumsum() - 1

# %% [markdown]
# ## Create running total of pitches thrown in each game

# %%
madmax['pitch_game'] = madmax.groupby(['game_date'])['pitch'].cumsum() - 1

# %%
# madmax.loc[madmax.game_date == '2019-03-28']

# %% [markdown]
# ## Create running total of pitches thrown to each batter per game

# %%
madmax['pitch_bat_gm'] = madmax.groupby(['game_date', 'batter'])['pitch'].cumsum() - 1

# %%
madmax.pitch_number = madmax.pitch_number - 1

# %%
madmax.loc[madmax.batter == 607043]
# Out:
#      pitch_type   game_date          sv_id  batter  pitch_number  \
# 2769         FF  2019-03-28  190328_170717  607043             0
# 2768         FF  2019-03-28  190328_170732  607043             1
# 2767         FF  2019-03-28  190328_170752  607043             2
# 2736         FF  2019-03-28  190328_174239  607043             0
# 2735         CU  2019-03-28  190328_174257  607043             1
# 2734         FF  2019-03-28  190328_174315  607043             2
# 2733         FF  2019-03-28  190328_174331  607043             3
# 2732         CH  2019-03-28  190328_174350  607043             4
# 2731         FC  2019-03-28  190328_174416  607043             5
# 2702         CH  2019-03-28  190328_182744  607043             0
# 2701         CH  2019-03-28  190328_182803  607043             1
# 2700         FF  2019-03-28  190328_182823  607043             2
# 2664         FF  2019-03-28  190328_190845  607043             0
# 2663         CU  2019-03-28  190328_190915  607043             1
# 2662         CH  2019-03-28  190328_190945  607043             2
# 2661         CH  2019-03-28  190328_191011  607043             3
# 2493         FF  2019-04-07  190407_185807  607043             0
# 2492         FF  2019-04-07  190407_185822  607043             1
# 2491         FF  2019-04-07  190407_185840  607043             2
# 2490         SL  2019-04-07  190407_185857  607043             3
# 2467         FF  2019-04-07  190407_195312  607043             0
# 2466         FF  2019-04-07  190407_195335  607043             1
# 2465         FF  2019-04-07  190407_195412  607043             2
# 476          FF  2019-09-03  190903_232619  607043             0
# 475          FF  2019-09-03  190903_232636  607043             1
# 474          CH  2019-09-03  190903_232658  607043             2
# 473          CH  2019-09-03  190903_232718  607043             3
# 472          FF  2019-09-03  190903_232743  607043             4
# 471          CU  2019-09-03  190903_232811  607043             5
# 470          FF  2019-09-03  190903_232836  607043             6
# 447          FF  2019-09-03  190904_000222  607043             0
# 446          FF  2019-09-03  190904_000248  607043             1
# 445          FF  2019-09-03  190904_000315  607043             2
# 444          FF  2019-09-03  190904_000355  607043             3
# 418          CU  2019-09-03  190904_003641  607043             0
# 417          CU  2019-09-03  190904_003700  607043             1
# 416          FC  2019-09-03  190904_003725  607043             2
# 415          FF  2019-09-03  190904_003751  607043             3
# 414          FC  2019-09-03  190904_003819  607043             4
# 413          FC  2019-09-03  190904_003901  607043             5
#
#       release_speed  zone stand home_team  on_3b  ...  nats_score  \
# 2769           93.7   6.0     L       WSH      0  ...           0
# 2768           94.2   5.0     L       WSH      0  ...           0
# 2767           96.3   5.0     L       WSH      0  ...           0
# 2736           96.5  14.0     L       WSH      0  ...           0
# 2735           79.5  11.0     L       WSH      0  ...           0
# 2734           96.3  11.0     L       WSH      0  ...           0
# 2733           94.0   7.0     L       WSH      0  ...           0
# 2732           85.8   7.0     L       WSH      0  ...           0
# 2731           91.8  14.0     L       WSH      0  ...           0
# 2702           83.8  13.0     L       WSH      0  ...           0
# 2701           83.9  13.0     L       WSH      0  ...           0
# 2700           94.1   3.0     L       WSH      0  ...           0
# 2664           93.1   6.0     L       WSH      0  ...           0
# 2663           76.2  13.0     L       WSH      0  ...           0
# 2662           82.4  13.0     L       WSH      0  ...           0
# 2661           83.8  13.0     L       WSH      0  ...           0
# 2493           92.8  14.0     L       NYM      0  ...           7
# 2492           94.1  12.0     L       NYM      0  ...           7
# 2491           95.3  14.0     L       NYM      0  ...           7
# 2490           87.9   5.0     L       NYM      0  ...           7
# 2467           94.0  14.0     L       NYM      0  ...          12
# 2466           93.0   1.0     L       NYM      0  ...          12
# 2465           93.3   8.0     L       NYM      0  ...          12
# 476            94.9   9.0     L       WSH      0  ...           1
# 475            94.7   2.0     L       WSH      0  ...           1
# 474            85.4  13.0     L       WSH      0  ...           1
# 473            86.2  13.0     L       WSH      0  ...           1
# 472            96.0   4.0     L       WSH      0  ...           1
# 471            81.3  13.0     L       WSH      0  ...           1
# 470            96.5  13.0     L       WSH      0  ...           1
# 447            95.3   5.0     L       WSH      1  ...           1
# 446            94.5  11.0     L       WSH      1  ...           1
# 445            95.4   5.0     L       WSH      1  ...           1
# 444            96.6   8.0     L       WSH      1  ...           1
# 418            77.8  11.0     L       WSH      0  ...           1
# 417            79.7  13.0     L       WSH      0  ...           1
# 416            89.6   5.0     L       WSH      0  ...           1
# 415            94.4   6.0     L       WSH      0  ...           1
# 414            88.5  13.0     L       WSH      0  ...           1
# 413            90.5   5.0     L       WSH      0  ...           1
#
#       if_fielding_alignment  of_fielding_alignment  nats_home1_away0  \
# 2769          Infield shift               Standard                 1
# 2768          Infield shift               Standard                 1
# 2767          Infield shift               Standard                 1
# 2736          Infield shift               Standard                 1
# 2735          Infield shift               Standard                 1
# 2734          Infield shift               Standard                 1
# 2733          Infield shift               Standard                 1
# 2732          Infield shift               Standard                 1
# 2731          Infield shift               Standard                 1
# 2702          Infield shift               Standard                 1
# 2701          Infield shift               Standard                 1
# 2700          Infield shift               Standard                 1
# 2664               Standard               Standard                 1
# 2663               Standard               Standard                 1
# 2662          Infield shift               Standard                 1
# 2661          Infield shift               Standard                 1
# 2493          Infield shift               Standard                 0
# 2492          Infield shift               Standard                 0
# 2491          Infield shift               Standard                 0
# 2490          Infield shift               Standard                 0
# 2467               Standard               Standard                 0
# 2466               Standard               Standard                 0
# 2465               Standard               Standard                 0
# 476               Strategic               Standard                 1
# 475               Strategic               Standard                 1
# 474               Strategic               Standard                 1
# 473               Strategic               Standard                 1
# 472                Standard               Standard                 1
# 471                Standard               Standard                 1
# 470                Standard               Standard                 1
# 447                Standard               Standard                 1
# 446                Standard               Standard                 1
# 445                Standard               Standard                 1
# 444                Standard               Standard                 1
# 418                Standard               Standard                 1
# 417                Standard               Standard                 1
# 416                Standard               Standard                 1
# 415                Standard               Standard                 1
# 414                Standard               Standard                 1
# 413                Standard               Standard                 1
#
#       balls_strikes     all_runners  pitch pitch_season pitch_game  \
# 2769            0_0  fb:0_sb:0_tb:0      1            0          0
# 2768            0_1  fb:0_sb:0_tb:0      1            1          1
# 2767            0_2  fb:0_sb:0_tb:0      1            2          2
# 2736            0_0  fb:0_sb:0_tb:0      1           33         33
# 2735            1_0  fb:0_sb:0_tb:0      1           34         34
# 2734            2_0  fb:0_sb:0_tb:0      1           35         35
# 2733            3_0  fb:0_sb:0_tb:0      1           36         36
# 2732            3_1  fb:0_sb:0_tb:0      1           37         37
# 2731            3_2  fb:0_sb:0_tb:0      1           38         38
# 2702            0_0  fb:0_sb:0_tb:0      1           67         67
# 2701            0_1  fb:0_sb:0_tb:0      1           68         68
# 2700            0_2  fb:0_sb:0_tb:0      1           69         69
# 2664            0_0  fb:1_sb:0_tb:0      1          105        105
# 2663            0_1  fb:1_sb:0_tb:0      1          106        106
# 2662            0_2  fb:1_sb:0_tb:0      1          107        107
# 2661            1_2  fb:1_sb:0_tb:0      1          108        108
# 2493            0_0  fb:0_sb:0_tb:0      1          276         71
# 2492            1_0  fb:0_sb:0_tb:0      1          277         72
# 2491            1_1  fb:0_sb:0_tb:0      1          278         73
# 2490            2_1  fb:0_sb:0_tb:0      1          279         74
# 2467            0_0  fb:1_sb:1_tb:0      1          302         97
# 2466            1_0  fb:1_sb:1_tb:0      1          303         98
# 2465            2_0  fb:1_sb:1_tb:0      1          304         99
# 476             0_0  fb:0_sb:0_tb:0      1         2293         20
# 475             0_1  fb:0_sb:0_tb:0      1         2294         21
# 474             0_2  fb:0_sb:0_tb:0      1         2295         22
# 473             1_2  fb:0_sb:0_tb:0      1         2296         23
# 472             2_2  fb:0_sb:0_tb:0      1         2297         24
# 471             2_2  fb:0_sb:0_tb:0      1         2298         25
# 470             3_2  fb:0_sb:0_tb:0      1         2299         26
# 447             0_0  fb:0_sb:1_tb:1      1         2322         49
# 446             0_1  fb:0_sb:1_tb:1      1         2323         50
# 445             1_1  fb:0_sb:1_tb:1      1         2324         51
# 444             1_2  fb:0_sb:1_tb:1      1         2325         52
# 418             0_0  fb:0_sb:0_tb:0      1         2351         78
# 417             1_0  fb:0_sb:0_tb:0      1         2352         79
# 416             2_0  fb:0_sb:0_tb:0      1         2353         80
# 415             2_1  fb:0_sb:0_tb:0      1         2354         81
# 414             2_2  fb:0_sb:0_tb:0      1         2355         82
# 413             3_2  fb:0_sb:0_tb:0      1         2356         83
#
#       pitch_bat_gm
# 2769             0
# 2768             1
# 2767             2
# 2736             3
# 2735             4
# 2734             5
# 2733             6
# 2732             7
# 2731             8
# 2702             9
# 2701            10
# 2700            11
# 2664            12
# 2663            13
# 2662            14
# 2661            15
# 2493             0
# 2492             1
# 2491             2
# 2490             3
# 2467             4
# 2466             5
# 2465             6
# 476              0
# 475              1
# 474              2
# 473              3
# 472              4
# 471              5
# 470              6
# 447              7
# 446              8
# 445              9
# 444             10
# 418             11
# 417             12
# 416             13
# 415             14
# 414             15
# 413             16
#
# [40 rows x 26 columns]

# %% [markdown]
# ## Reorder columns

# %%
madmax = madmax.drop(columns = ['pitch'])

# %%
madmax.columns
# Out:
# Index(['pitch_type', 'game_date', 'sv_id', 'batter', 'pitch_number',
#        'release_speed', 'zone', 'stand', 'home_team', 'on_3b', 'on_2b',
#        'on_1b', 'outs_when_up', 'inning', 'release_spin_rate', 'opp_score',
#        'nats_score', 'if_fielding_alignment', 'of_fielding_alignment',
#        'nats_home1_away0', 'balls_strikes', 'all_runners', 'pitch_season',
#        'pitch_game', 'pitch_bat_gm'],
#       dtype='object')

# %%
madmax[['pitch_type', 'game_date', 'sv_id', 'batter', 
        'pitch_number', 'pitch_bat_gm', 'pitch_game', 'pitch_season', 
        'release_speed', 'zone', 'stand', 'home_team', 
        'on_3b', 'on_2b', 'on_1b', 'outs_when_up', 'inning', 
        'release_spin_rate', 'opp_score', 'nats_score', 'if_fielding_alignment', 'of_fielding_alignment',
        'nats_home1_away0', 'balls_strikes', 'all_runners']]
# Out:
#      pitch_type   game_date          sv_id  batter  pitch_number  \
# 2769         FF  2019-03-28  190328_170717  607043             0
# 2768         FF  2019-03-28  190328_170732  607043             1
# 2767         FF  2019-03-28  190328_170752  607043             2
# 2766         SL  2019-03-28  190328_170825  624413             0
# 2765         FF  2019-03-28  190328_170842  624413             1
# ...         ...         ...            ...     ...           ...
# 4            CU  2019-09-24  190925_005705  664068             1
# 3            SL  2019-09-24  190925_005726  664068             2
# 2            FF  2019-09-24  190925_005750  664068             3
# 1            CH  2019-09-24  190925_005823  664068             4
# 0            FF  2019-09-24  190925_005920  656514             0
#
#       pitch_bat_gm  pitch_game  pitch_season  release_speed  zone  ...  \
# 2769             0           0             0           93.7   6.0  ...
# 2768             1           1             1           94.2   5.0  ...
# 2767             2           2             2           96.3   5.0  ...
# 2766             0           3             3           85.6   6.0  ...
# 2765             1           4             4           95.5  12.0  ...
# ...            ...         ...           ...            ...   ...  ...
# 4               11          96          2765           79.1   4.0  ...
# 3               12          97          2766           84.8  14.0  ...
# 2               13          98          2767           97.4   8.0  ...
# 1               14          99          2768           84.4   9.0  ...
# 0                7         100          2769           92.7   6.0  ...
#
#      outs_when_up inning  release_spin_rate  opp_score  nats_score  \
# 2769            0      1             2584.0          0           0
# 2768            0      1             2545.0          0           0
# 2767            0      1             2738.0          0           0
# 2766            1      1             2370.0          0           0
# 2765            1      1             2632.0          0           0
# ...           ...    ...                ...        ...         ...
# 4               2      6             2818.0          4           2
# 3               2      6             2295.0          4           2
# 2               2      6             2465.0          4           2
# 1               2      6             1494.0          4           2
# 0               2      6             2299.0          4           2
#
#       if_fielding_alignment  of_fielding_alignment  nats_home1_away0  \
# 2769          Infield shift               Standard                 1
# 2768          Infield shift               Standard                 1
# 2767          Infield shift               Standard                 1
# 2766          Infield shift               Standard                 1
# 2765          Infield shift               Standard                 1
# ...                     ...                    ...               ...
# 4                  Standard               Standard                 1
# 3                  Standard               Standard                 1
# 2                  Standard               Standard                 1
# 1                  Standard               Standard                 1
# 0             Infield shift               Standard                 1
#
#       balls_strikes     all_runners
# 2769            0_0  fb:0_sb:0_tb:0
# 2768            0_1  fb:0_sb:0_tb:0
# 2767            0_2  fb:0_sb:0_tb:0
# 2766            0_0  fb:0_sb:0_tb:0
# 2765            0_1  fb:0_sb:0_tb:0
# ...             ...             ...
# 4               0_1  fb:0_sb:0_tb:0
# 3               0_2  fb:0_sb:0_tb:0
# 2               1_2  fb:0_sb:0_tb:0
# 1               1_2  fb:0_sb:0_tb:0
# 0               0_0  fb:1_sb:0_tb:0
#
# [2770 rows x 25 columns]

# %%
outfile = open('../../data/processed/scherzer/scherzer_clean_new_features.pickle','wb')
pickle.dump(madmax ,outfile)
outfile.close()
